# %% [markdown]
# # streamlit을 활용해서 ETL 대시보드를 만들어보세요
# ## 다음 항목 중 (*표시 항목은 반드시 포함하여) 최소 4가지 이상 구현하고 각 항목의 기능에 대한 파이썬 코드를 각 셀에 붙여넣으세요.
# - data.csv를 이용해서 데이터를 제공하는 API 구현
# - 파일 업로드 후 데이터프레임 생성하는 기능
# - 업로드 파일 EDA
# - API로 부터 데이터 수집하여 api_data에 csv를 생성
# - api_data 폴더 내 csv를 읽어서 전처리 후 working directory에 하나의 csv 생성: pkl로 저장된 파이프라인 사용, prefect로 전처리 적용 권장
# - 수집한 csv들을 postgres db(설치 문제 있을 경우, sqlite)에 넣고, 처리된 csv는 별도 폴더(api_backup)로 이동
# - 파일 저장한 db 내 내용 조회

# %%
# data.csv를 이용해서 데이터를 제공하는 API 구현

# %%
# 파일 업로드 후 데이터프레임 생성하는 기능

# %%
# 업로드 파일 EDA

# %%
# API로 부터 데이터 수집하여 api_data에 csv를 생성

# %%
# api_data 폴더 내 csv를 읽어서 전처리 후 working directory에 하나의 csv 생성: pkl로 저장된 파이프라인 사용, prefect로 전처리 적용 권장

# %%
# 수집한 csv들을 postgres db(설치 문제 있을 경우, sqlite)에 넣고, 처리된 csv는 별도 폴더(api_backup)로 이동

# %%
# 파일 저장한 db 내 내용 조회
