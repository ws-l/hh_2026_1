# %% [markdown]
# #1. CNC Virtual Data set _v2의 폴더 내 파일들을 읽어서 하나의 데이터프레임으로 만드세요
# 폴더명은 처리하기 편하도록 변경하셔도 되세요
#
# #2. 1의 데이터에 대해 전처리(imputing, scaling, ohe)를 적용하고 X_train, X_test, y_train, y_test를 만드세요
# - y변수: Matching Process,  -X변수: 나머지
#
# #3. satimages.csv에 대해서 파이프라인을 적용하세요
# y변수: y, X: 나머지
#
# #4. 위 내용들을 아래 노트에서 작업하시고 결과가 보여지도록 하세요. 이후 사번.zip으로 압축 후 LMS에 1) 화요일반은 월요일 23시까지 2) 수요일반은 화요일 23시까지, 3) 목요일반은 수요일 23시까지 제출해주세요.
